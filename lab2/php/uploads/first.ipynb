# %%
#1.Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#2.Load the dataset 
df=pd.read_csv("C:/Users/Chinnu/Desktop/lab_1/data.csv")
#3.Display the number of rows and columns
print("Rows:",df.shape[0])
print("Columns:",df.shape[1])
#4.Print column names
print(df.columns)
#5.Display first 5 rows
print(df.head())
#6.Check data type of each column
print(df .dtypes)
#7. Identify number of missing values in each column 
print(df. isnull().sum())
#8. Fill missing values in numerical columns using mean 
num_cols=df.select_dtypes(include=np.number).columns
df[num_cols]=df[num_cols].fillna(df[num_cols].mean())
#9. Fill missing values in categorical columns using mode 
cat_cols= df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col]=df[col].fillna(df[col].mode()[0])
#10.Verify no missing values remain 
print (df.isnull().sum())
                
#11. Caluclate mean for numerical columns 
print("Mean:\n", df[num_cols].mean())
#12. Calculte median for numerical columns 
print ("Median:\n",df[num_cols].median())
#13. Calculate standard deviation for numerical columns
print ("standard deviation:\n",df[num_cols].std())
#14. Find minimum and maximum values 
print ("Minimum:\n", df[num_cols].min())
print ("Maximum:\n", df[num_cols].max())
#15. Generate summary using describe ()
print(df.describe())
#16. Create histogram for purchase amount column 
plt. figure()
plt.hist(df['purchase_amount'])
plt.xlabel('purchase amount')
plt.ylabel('Frequency')
plt.title('Histogram of purchase amount')
plt.show()
#17. Bar chart 
plt.figure()
df['product_category'].value_counts().plot(kind='bar')
plt.xlabel('purchase category')
plt.ylabel('Number of customers')
plt.title('customers by product category')
plt.show()
#create a box plot for purchase amount
plt.boxplot(df['purchase_amount'])
plt.title("Box plot of purchase amount")
plt.ylabel("Purchase Amount")
plt.show()
#add age column 
df['age']=[25,30,28,35,33]
plt.scatter(df['age'],df['purchase_amount'])
plt.xlabel("Age")
plt.ylabel("Purchase Amount")
plt.title("Age vs Purchase Amount")
plt.show()
#Display a correlation hetmap for numerical columns
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True),
annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Rows: 5
# Columns: 4
# Index(['customer_id', 'customer_name', 'product_category', 'purchase_amount'], dtype='object')
#    customer_id customer_name product_category  purchase_amount
# 0            1          Ravi      Electronics          25000.0
# 1            2          Sita         Clothing           1500.0
# 2            3         Arjun      Electronics              NaN
# 3            4         Meena          Grocery           2500.0
# 4            5       Krishna         Clothing              NaN
# customer_id           int64
# customer_name        object
# product_category     object
# purchase_amount     float64
# dtype: object
# customer_id         0
# customer_name       0
# product_category    0
# purchase_amount     2
# dtype: int64
# customer_id         0
# customer_name       0
# product_category    0
# purchase_amount     0
# dtype: int64
# Mean:
#  customer_id           3.000000
# purchase_amount    9666.666667
# dtype: float64
# Median:
# ...
